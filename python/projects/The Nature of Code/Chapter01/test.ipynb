# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

ax.set_xlim(-5, 5)
ax.set_ylim(0, 10)
ax.set_zlim(-5, 5)

ball, = ax.plot(
    [0], [5], [0],
    "o"
)

plt.show()
